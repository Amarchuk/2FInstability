# %% [markdown]
# # u7989 =n4725
# ## Есть все
#
# Необходимые данные:

# %%
from IPython.display import Image

# %% [markdown]
# ## Кинематические данные по звездам
#
# Дисперсии скоростей и кривая вращения - http://adsabs.harvard.edu/cgi-bin/bib_query?1999A%26AS..136..509H до ~50'' (1 разрез)

# %%
Image('u7989_d.png')

# %% [markdown]
# ## Данные по фотометрии
#
# Декомпозиция: галактика  из выборки Ноордермеера - есть R и B

# %% [markdown]
# ## Данные по газу
#
# Кривая вращения - нет у Ноордермеера, есть тут http://www.aanda.org/articles/aa/pdf/2011/06/aa16177-10.pdf
#
#
# $\Sigma_{HI}$ и $\Sigma_{H_2}$ https://arxiv.org/pdf/1608.06735v1.pdf
# $\Sigma_{HI}$ из Ноордермеера

# %%
Image('u7989.png')

# %% [markdown]
# ## Области звездообразования
#
# $\rm{H_{\alpha}}$, $UV$
#
# есть $\rm{H_{\alpha}}$ в Hameed 2005 http://iopscience.iop.org/article/10.1086/430211/pdf

# %%
Image('n4725_halpha.png')
