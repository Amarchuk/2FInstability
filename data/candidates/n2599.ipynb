# %% [markdown]
# # NGC 2599 = UGC 4458

# %%
from IPython.display import Image

# %% [markdown]
# ## Кинематические данные по звездам
#
# Дисперсии скоростей и кривая вращения

# %%
Image('u4458_d.png')

# %% [markdown]
# ## Данные по фотометрии
#
# Декомпозиция: галактика  из выборки Ноордермеера - есть R и B

# %% [markdown]
# ## Данные по газу
#
# Кривая вращения - есть у Ноордермеера
#
# $\Sigma_g$ - есть у Ноордермеера

# %%
Image('u4458.png')

# %% [markdown]
# ## Области звездообразования
#
# $\rm{H_{\alpha}}$, $UV$
