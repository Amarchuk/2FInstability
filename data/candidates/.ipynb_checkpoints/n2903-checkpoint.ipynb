# %% [markdown]
# # u5079 =n2903
#
# Необходимые данные:

# %%
from IPython.display import Image

# %% [markdown]
# ## Кинематические данные по звездам
#
# Дисперсии скоростей и кривая вращения - есть в http://adsabs.harvard.edu/cgi-bin/bib_query?1998A%26AS..133..317H до почти 50'' (2 разреза)

# %%
Image('u5079.png')

# %% [markdown]
# ## Данные по фотометрии
#
# Декомпозиция и

# %% [markdown]
# ## Данные по газу
#
# Кривая вращения,
#
#
# $\Sigma_{HI}$ и $\Sigma_{H_2}$ https://arxiv.org/pdf/1608.06735v1.pdf

# %% [markdown]
# ## Области звездообразования
#
# $\rm{H_{\alpha}}$, $UV$
