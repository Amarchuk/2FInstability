# %% [markdown]
# # NGC 3067 = UGC 5351
#
# Необходимые данные:

# %%
from IPython.display import Image

# %% [markdown]
# ## Кинематические данные по звездам
#
# Дисперсии скоростей и кривая вращения - http://adsabs.harvard.edu/cgi-bin/bib_query?1999A%26AS..136..509H до ~20'' (1 разрез, плохое качество)

# %% [markdown]
# ## Данные по фотометрии
#
# Есть в тезисах Ноордермеера - но фотометрии там нет.

# %% [markdown]
# ## Данные по газу
#
# Кривая вращения,
#
# $\Sigma_g$ - из Ноордермеера $HI$

# %%
Image('u5351.png')

# %% [markdown]
# ## Области звездообразования
#
# $\rm{H_{\alpha}}$, $UV$
