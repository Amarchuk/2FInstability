# %% [markdown]
# # NGC 3190 = UGC 5559
#
# Она судя по всему сложная, есть сверхновая
#
# Необходимые данные:

# %%
from IPython.display import Image

# %% [markdown]
# ## Кинематические данные по звездам
#
# Дисперсии скоростей и кривая вращения - есть в http://adsabs.harvard.edu/cgi-bin/bib_query?1998A%26AS..133..317H до ~ 30'' (1 разрез)

# %%
Image('u5559_d.png')

# %% [markdown]
# ## Данные по фотометрии
#
# Есть у Ноордермеера - но фотометрии нет
#
# В http://iopscience.iop.org/article/10.1088/0004-637X/703/2/1569/pdf есть UV, Optical (SDSS), and Near-IR Asymptotic Magnitudes (интегральные звездные величины в куче полос)
#
# В http://articles.adsabs.harvard.edu/cgi-bin/nph-iarticle_query?1996A%26AS..118..111H&amp;data_type=PDF_HIGH&amp;whole_paper=YES&amp;type=PRINTER&amp;filetype=.pdf есть вроде B,R,I фотометрия без декомпозиции

# %% [markdown]
# ## Данные по газу
#
# Кривая вращения - у Ноордермеера нет
#
# $\Sigma_g$ - из Ноордермеера $HI$

# %%
Image('u5559.png')

# %% [markdown]
# ## Области звездообразования
#
# $\rm{H_{\alpha}}$, $UV$

# %% [markdown]
# ## Дополнительно
#
# из https://arxiv.org/pdf/1406.0828v1.pdf

# %%
Image('n3190_strange.png')

# %% [markdown]
# Из http://mnras.oxfordjournals.org/content/385/2/553.full.pdf (очень странно - не та галактика на карте)

# %%
Image('n3190_halpha.png')
