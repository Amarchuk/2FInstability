# %%
from IPython.display import Image

# %% [markdown]
# [Leroy (2008)](https://ui.adsabs.harvard.edu/#abs/2008AJ....136.2782L/abstract) *The Star Formation Efficiency in Nearby Galaxies: Measuring Where Gas Forms Stars Effectively*

# %%
Image('leroy_other_mechanisms.png')

# %% [markdown]
# Более новые законы из молекулярного газа: *H2-based star formation laws in hierarchical models of galaxy formation* (https://arxiv.org/pdf/1611.09372.pdf)

# %% [markdown]
# The Krumholz, McKee & Tumlinson (2009b) star formation law (KMT09)

# %%
Image('KMT09.png')

# %% [markdown]
# The Krumholz (2013) star formation law (K13)

# %%
Image('K13.png')

# %% [markdown]
# The Gnedin & Kravtsov (2011) star formation law (GK11)

# %%
Image('GK11.png')
